# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000)

# %%
equation1= 2.5 * t

# %%
equation2 = 3 * (t-5)

# %%
plt.title("Graph of Two Equations")
plt.xlabel("Time (t)")
plt.ylabel("Value")
plt.xlim([0, 40])
plt.ylim([0, 100])
plt.plot(t, equation1,color='blue')
plt.plot(t, equation2,color='orange')
plt.axhline(30, color='purple', linestyle='--', lw=0.5)
_= plt.axvline(75, color='purple', linestyle='--', lw=0.5)

# %% [markdown]
# Scalar Tensors

# %%
x = 25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y = 3
3
# Out:
# 3

# %%
pysum = x+ y
pysum
# Out:
# 28

# %%
import torch

# %%
x_pt = torch.tensor(26)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(27, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=27>

# %%
# Mobile Data Bill Calculator

def calculate_extra_charges(usage):
    """Calculate extra data charges - 25 Points"""
    if usage > 8:
        overage = usage - 8
        extra_charges = overage * 3
        return extra_charges
    else:
        return 0.0

def apply_discount(extra):
    """Apply discount if extra charges exceed $20 - 15 Points"""
    if extra > 20:
        discount = extra * 0.10
        return extra - discount
    else:
        return extra

def calculate_tax(amount):
    """Calculate 6% tax on the amount - 15 Points"""
    tax = amount * 0.06
    return tax

def calculate_total_bill(base, extra, tax):
    """Calculate total bill - 15 points"""
    total = base + extra + tax
    return total

def display_bill(usage, BASE_PLAN, extra, discount, tax, total):
    """Display detailed bill - 15 Points"""
    print("----- MOBILE DATA BILL -----")
    print(f"Data Used: {usage} GB")
    print(f"Base Plan: ${BASE_PLAN:.2f}")
    print(f"Extra Charges: ${extra + discount:.2f}")
    if discount > 0:
        print(f"Discount Applied: ${discount:.2f}")
    print(f"Subtotal: ${BASE_PLAN + extra:.2f}")
    print(f"Tax (6%): ${tax:.2f}")
    print(f"Total Amount Due: ${total:.2f}")
    print("----------------------------")

# Main Program - Scanning input from user and Function calling - 15 Points
BASE_PLAN = 25
usage = float(input("Enter data usage (GB): "))

# Calculate all components
extra_charges_before_discount = calculate_extra_charges(usage)
extra_charges_after_discount = apply_discount(extra_charges_before_discount)
discount_amount = extra_charges_before_discount - extra_charges_after_discount
subtotal = BASE_PLAN + extra_charges_after_discount
tax = calculate_tax(subtotal)
total = calculate_total_bill(BASE_PLAN, extra_charges_after_discount, tax)

# Display the bill
display_bill(usage, BASE_PLAN, extra_charges_after_discount, discount_amount, tax, total)
